# %%
	
from time import time
from copy import copy
from collections import namedtuple

week_schedule = {1: "Понеділок", 2: "Вівторок", 3: "Середа", 4: "Четвер", 5: "П'ятниця"}
time_schedule = {
    1: "8:40-10:15",
    2: "10:35-12:10",
    3: "12:20-13:55",
}

Classroom = namedtuple("Classroom", "room is_big")
Time = namedtuple("Time", "weekday time")
Teacher = namedtuple("Teacher", "name")
Subject = namedtuple("Subject", "name")
Group = namedtuple("Group", "name")
Lesson = namedtuple("Lesson", "teacher subject group is_lecture per_week")
Schedule = namedtuple("Schedule", "lessons classrooms times")
OptionEl = namedtuple("OptionEl", "day time room")

classrooms = [
    Classroom(409, True),
    Classroom(43, True),
    Classroom(42, True),
    Classroom(305, False),
    Classroom(307, False),
    Classroom(203, False),
]

schedule = [
    Time(w, n)
    for w in range(1, len(week_schedule.keys()) + 1)
    for n in range(1, len(week_schedule.keys()) + 1)
]

teachers = [
    Teacher(name)
    for name in ('0 Пашко',
                 '1 Вергунова',
                 '2 Бобиль',
                 '3 Закала',
                 '4 Зінько',
                 '5 Мащенко',
                 '6 Тарануха',
                 '7 Федорус',
                 '8 Мисечко',
                 '9 Ткаченко',
                 '10 Терещенко',
                 '11 Свистунов',
                 '12 Красовська',
                 '13 Шишацька',
                 '14 Дорошенко',
                 '15 Крак',
                 '16 Чернега',
                 '17 Злотник',
                 '18 Башняков',
                 '19 Коробова',
                 '20 Коваль',
                 '21 Криволап',
                 '22 Галавай',
                 '23 Башук')
]

subjects = [
    Subject(name)
    for name in (
        "0 Статистичне моделювання в задачах штучного інтелекту",
        "1 Складність алгоритмів",
        "2 Нейронні мережі",
        "3 Теорія прийняття рішень",
        "4 Інтелектуальні системи",
        "5 Інформаційні технології",
        "6 Основи комп\'ютерної лінгвістики",
        "7 Іноземна мова",
        "8 Розробка ПЗ під мобільні платформи",
        "9 Основи управління ІТ-проєктами",
        "10 Методи паралельних обчислень",
        "11 Розробка ПЗ",
        "12 Проблеми штучного інтелекту",
        "13 Розробка ПЗ під мобільні платформи",
        "14 Алгоритміка",
        "15 Інформаційні системи",
        "16 Теорія прийняття рішень",
        "17 Інтелектуальні системи",
    )
]


groups = [
    Group(name)
    for name in (
        "ТТП-41",
        "ТТП-42",
        "ТК-41",
        "МІ-41",
        "МІ-42",
    )
]


lessons = [
    Lesson(teachers[0], subjects[0], groups[0:5], True, 1),
    Lesson(teachers[1], subjects[1], groups[4:5], True, 1),
    Lesson(teachers[2], subjects[2], groups[4:5], False, 2),
    Lesson(teachers[2], subjects[2], groups[0], True, 2),
    Lesson(teachers[3], subjects[12], groups[0], True, 1),
    Lesson(teachers[4], subjects[4], groups[0:5], True, 1),
    Lesson(teachers[5], subjects[16], groups[0:5], True, 1),
    Lesson(teachers[4], subjects[16], groups[0], False, 1),
    Lesson(teachers[9], subjects[6], groups[0:5], True, 1),
    Lesson(teachers[13], subjects[4], groups[0], False, 1),
    Lesson(teachers[13], subjects[16], groups[0], True, 2),
    Lesson(teachers[13], subjects[16], groups[0], True, 2),
    Lesson(teachers[21], subjects[4], groups[1], False, 1),
    Lesson(teachers[6], subjects[4], groups[2], False, 1),
    Lesson(teachers[7], subjects[4], groups[1], False, 1),
    Lesson(teachers[12], subjects[7], groups[2], False, 1),
    Lesson(teachers[8], subjects[3], groups[1:3], True, 1),
    Lesson(teachers[10], subjects[15], groups[1], False, 2),
    Lesson(teachers[10], subjects[13], groups[1], False, 2),
    Lesson(teachers[10], subjects[15], groups[2], False, 2),
    Lesson(teachers[10], subjects[15], groups[2], False, 2),
    Lesson(teachers[11], subjects[8], groups[1:3], True, 2),
    Lesson(teachers[11], subjects[8], groups[1:3], True, 2),
    Lesson(teachers[12], subjects[9], groups[1:3], True, 2),
    Lesson(teachers[12], subjects[9], groups[1:3], True, 2),
    Lesson(teachers[18], subjects[10], groups[1:3], True, 1),
    Lesson(teachers[5], subjects[16], groups[3], False, 1),
    Lesson(teachers[5], subjects[16], groups[4], False, 1),
    Lesson(teachers[6], subjects[4], groups[3], False, 1),
    Lesson(teachers[6], subjects[4], groups[4], False, 1),
    Lesson(teachers[14], subjects[12], groups[3:5], True, 2),
    Lesson(teachers[14], subjects[12], groups[3:5], True, 2),
    Lesson(teachers[15], subjects[13], groups[3:5], False, 1),
    Lesson(teachers[16], subjects[11], groups[3:5], True, 2),
    Lesson(teachers[16], subjects[11], groups[3:5], True, 2),
    Lesson(teachers[17], subjects[14], groups[3:5], True, 1),
    Lesson(teachers[17], subjects[17], groups[3:5], True, 1),
]

def run_MinimumRemainingValues():
    return backtrack(MinimumRemainingValues, init_options(), Schedule([], [], []))


def run_LeastConstrainingValue():
    return backtrack(LeastConstrainingValue, init_options(), Schedule([], [], []))


def run_degree():
    return backtrack(degree, init_options(), Schedule([], [], []))


def init_options():
    options = {}
    buf = []
    buf_lecture = []
    for day in week_schedule.keys():
        for time_slot in time_schedule.keys():
            for room in classrooms:
                buf.append(OptionEl(day, time_slot, room))
                if room.is_big:
                    buf_lecture.append(OptionEl(day, time_slot, room))
    for i in range(len(lessons)):
        if lessons[i].is_lecture:
            options[i] = copy(buf_lecture)
        else:
            options[i] = copy(buf)
    return options

def MinimumRemainingValues(options):
    min_len = len(week_schedule) * len(classrooms) * len(time_schedule) * 2
    ind = list(options.keys())[0]
    for key, value in options.items():
        if len(value) < min_len:
            min_len = len(value)
            ind = key
    return ind

def degree(options):
    counts = {}
    for key in options:
        counts[key] = 0 if lessons[key].is_lecture else 1
        for i in options:
            if i == key:
                continue
            if lessons[key].teacher == lessons[i].teacher:
                counts[key] += 1
            counts[key] += len(
                set(map(str, lessons[key].group)) & set(map(str, lessons[i].group))
            )

    ind = list(counts.keys())[0]
    max = 0
    for key, value in counts.items():
        if value > max:
            max = value
            ind = key
    return ind

def LeastConstrainingValue(options):
    counts = {}
    for i in options:
        counts[i] = 0
        for key in options:
            if i == key:
                continue

            for d in options[key]:
                if not (
                        d.day == options[i][0].day
                        and d.time == options[i][0].time
                        and d.room == options[i][0].room
                ) and not (
                        d.day == options[i][0].day
                        and d.time == options[i][0].time
                        and (
                        lessons[key].teacher == lessons[i].teacher
                        or set(map(str, lessons[key].group))
                        & set(map(str, lessons[i].group))
                    )
                ):
                    counts[i] += 1

    ind = list(counts.keys())[0]
    max = 0
    for key, value in counts.items():
        if value > max:
            max = value
            ind = key
    return ind


def backtrack(heuristic, options, schedule):
    if not options:
        return schedule
    ind = heuristic(options)
    if ind == -1:
        return None
    for d in options[ind]:
        sch_copy = copy(schedule)
        sch_copy.times.append(Time(d.day, d.time))
        sch_copy.classrooms.append(d.room)
        sch_copy.lessons.append(lessons[ind])

        dom_copy = copy(options)
        dom_copy.pop(ind)
        dom_copy = update_options(dom_copy, lessons[ind], d.day, d.time, d.room)

        res = backtrack(heuristic, dom_copy, sch_copy)
        if res:
            return res

    return None

def update_options(options, lesson, day, time, room):
    for key in options:
        buf = []
        for d in options[key]:
            if not (d.day == day and d.time == time and d.room == room) and not ( # ОБМЕЖЕННЯ
                d.day == day
                and d.time == time
                and (
                    lessons[key].teacher == lesson.teacher
                    or set(map(str, lessons[key].group)) & set(map(str, lesson.group))
                )
            ):
                buf.append(d)
        options[key] = buf

    return options

def print_schedule(solution: Schedule):
    for day in week_schedule:  
        print("\n" + "-" * 100)
        print(f"{week_schedule[day].upper()}")
        for time in time_schedule:  
            print("\n\n" + time_schedule[time])
            for c in classrooms:  
                print(f"\n{c}", end="\t\t")
                for i in range(len(solution.lessons)):  
                    if (solution.times[i].weekday == day and
                        solution.times[i].time == time and
                        solution.classrooms[i].room == c.room):
                            print("."*100)
                            print(solution.lessons[i], end="")
                            print("\n")


def main():
    solution = run_MinimumRemainingValues()
    print_schedule(solution)

    print()
    print("****************************************************************************************************")
    print("****************************************************************************************************")

    solution2 = run_LeastConstrainingValue()
    print_schedule(solution2)

    print()
    print("****************************************************************************************************")
    print("****************************************************************************************************")

    solution3 = run_degree()
    print_schedule(solution3)

    start_time = time()
    run_MinimumRemainingValues()
    print()
    print(f"MRV: {time() - start_time}")

    start_time = time()
    run_LeastConstrainingValue()
    print(f"LCV: {time() - start_time}")

    start_time = time()
    run_degree()
    print(f"Degree: {time() - start_time}")
if __name__ == "__main__":
    main()
# Out:
# ----------------------------------------------------------------------------------------------------
# ПОНЕДІЛОК
#
#
# 8:40-10:15
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='0 Пашко'), subject=Subject(name='0 Статистичне моделювання в задачах штучного інтелекту'), group=[Group(name='ТТП-41'), Group(name='ТТП-42'), Group(name='ТК-41'), Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=1)
#
#
# Classroom(room=43, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='2 Бобиль'), subject=Subject(name='2 Нейронні мережі'), group=Group(name='ТТП-41'), is_lecture=True, per_week=2)
#
#
# Classroom(room=42, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='12 Красовська'), subject=Subject(name='7 Іноземна мова'), group=Group(name='ТК-41'), is_lecture=False, per_week=1)
#
#
# Classroom(room=305, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='5 Мащенко'), subject=Subject(name='16 Теорія прийняття рішень'), group=Group(name='МІ-41'), is_lecture=False, per_week=1)
#
#
# Classroom(room=307, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='10 Терещенко'), subject=Subject(name='15 Інформаційні системи'), group=Group(name='ТТП-42'), is_lecture=False, per_week=2)
#
#
# Classroom(room=203, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='6 Тарануха'), subject=Subject(name='4 Інтелектуальні системи'), group=Group(name='МІ-42'), is_lecture=False, per_week=1)
#
#
#
# 10:35-12:10
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='1 Вергунова'), subject=Subject(name='1 Складність алгоритмів'), group=[Group(name='МІ-42')], is_lecture=True, per_week=1)
#
#
# Classroom(room=43, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='8 Мисечко'), subject=Subject(name='3 Теорія прийняття рішень'), group=[Group(name='ТТП-42'), Group(name='ТК-41')], is_lecture=True, per_week=1)
#
#
# Classroom(room=42, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='3 Закала'), subject=Subject(name='12 Проблеми штучного інтелекту'), group=Group(name='ТТП-41'), is_lecture=True, per_week=1)
#
#
# Classroom(room=305, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='5 Мащенко'), subject=Subject(name='16 Теорія прийняття рішень'), group=Group(name='МІ-42'), is_lecture=False, per_week=1)
#
#
# Classroom(room=307, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='6 Тарануха'), subject=Subject(name='4 Інтелектуальні системи'), group=Group(name='ТК-41'), is_lecture=False, per_week=1)
#
#
# Classroom(room=203, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='10 Терещенко'), subject=Subject(name='13 Розробка ПЗ під мобільні платформи'), group=Group(name='ТТП-42'), is_lecture=False, per_week=2)
#
#
#
# 12:20-13:55
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='4 Зінько'), subject=Subject(name='4 Інтелектуальні системи'), group=[Group(name='ТТП-41'), Group(name='ТТП-42'), Group(name='ТК-41'), Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=1)
#
#
# Classroom(room=43, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='13 Шишацька'), subject=Subject(name='16 Теорія прийняття рішень'), group=Group(name='ТТП-41'), is_lecture=True, per_week=2)
#
#
# Classroom(room=42, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='10 Терещенко'), subject=Subject(name='15 Інформаційні системи'), group=Group(name='ТК-41'), is_lecture=False, per_week=2)
#
#
# Classroom(room=305, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='21 Криволап'), subject=Subject(name='4 Інтелектуальні системи'), group=Group(name='ТТП-42'), is_lecture=False, per_week=1)
#
#
# Classroom(room=307, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='6 Тарануха'), subject=Subject(name='4 Інтелектуальні системи'), group=Group(name='МІ-41'), is_lecture=False, per_week=1)
#
#
# Classroom(room=203, is_big=False)
# ----------------------------------------------------------------------------------------------------
# ВІВТОРОК
#
#
# 8:40-10:15
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='5 Мащенко'), subject=Subject(name='16 Теорія прийняття рішень'), group=[Group(name='ТТП-41'), Group(name='ТТП-42'), Group(name='ТК-41'), Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=1)
#
#
# Classroom(room=43, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='13 Шишацька'), subject=Subject(name='16 Теорія прийняття рішень'), group=Group(name='ТТП-41'), is_lecture=True, per_week=2)
#
#
# Classroom(room=42, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='10 Терещенко'), subject=Subject(name='15 Інформаційні системи'), group=Group(name='ТК-41'), is_lecture=False, per_week=2)
#
#
# Classroom(room=305, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='7 Федорус'), subject=Subject(name='4 Інтелектуальні системи'), group=Group(name='ТТП-42'), is_lecture=False, per_week=1)
#
#
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
#
# 10:35-12:10
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='9 Ткаченко'), subject=Subject(name="6 Основи комп'ютерної лінгвістики"), group=[Group(name='ТТП-41'), Group(name='ТТП-42'), Group(name='ТК-41'), Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=1)
#
#
# Classroom(room=43, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='4 Зінько'), subject=Subject(name='16 Теорія прийняття рішень'), group=Group(name='ТТП-41'), is_lecture=False, per_week=1)
#
#
# Classroom(room=42, is_big=True)
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
#
# 12:20-13:55
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='14 Дорошенко'), subject=Subject(name='12 Проблеми штучного інтелекту'), group=[Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=2)
#
#
# Classroom(room=43, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='11 Свистунов'), subject=Subject(name='8 Розробка ПЗ під мобільні платформи'), group=[Group(name='ТТП-42'), Group(name='ТК-41')], is_lecture=True, per_week=2)
#
#
# Classroom(room=42, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='13 Шишацька'), subject=Subject(name='4 Інтелектуальні системи'), group=Group(name='ТТП-41'), is_lecture=False, per_week=1)
#
#
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
# ----------------------------------------------------------------------------------------------------
# СЕРЕДА
#
#
# 8:40-10:15
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='14 Дорошенко'), subject=Subject(name='12 Проблеми штучного інтелекту'), group=[Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=2)
#
#
# Classroom(room=43, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='11 Свистунов'), subject=Subject(name='8 Розробка ПЗ під мобільні платформи'), group=[Group(name='ТТП-42'), Group(name='ТК-41')], is_lecture=True, per_week=2)
#
#
# Classroom(room=42, is_big=True)
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
#
# 10:35-12:10
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='16 Чернега'), subject=Subject(name='11 Розробка ПЗ'), group=[Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=2)
#
#
# Classroom(room=43, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='12 Красовська'), subject=Subject(name='9 Основи управління ІТ-проєктами'), group=[Group(name='ТТП-42'), Group(name='ТК-41')], is_lecture=True, per_week=2)
#
#
# Classroom(room=42, is_big=True)
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
#
# 12:20-13:55
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='16 Чернега'), subject=Subject(name='11 Розробка ПЗ'), group=[Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=2)
#
#
# Classroom(room=43, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='12 Красовська'), subject=Subject(name='9 Основи управління ІТ-проєктами'), group=[Group(name='ТТП-42'), Group(name='ТК-41')], is_lecture=True, per_week=2)
#
#
# Classroom(room=42, is_big=True)
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
# ----------------------------------------------------------------------------------------------------
# ЧЕТВЕР
#
#
# 8:40-10:15
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='17 Злотник'), subject=Subject(name='14 Алгоритміка'), group=[Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=1)
#
#
# Classroom(room=43, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='18 Башняков'), subject=Subject(name='10 Методи паралельних обчислень'), group=[Group(name='ТТП-42'), Group(name='ТК-41')], is_lecture=True, per_week=1)
#
#
# Classroom(room=42, is_big=True)
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
#
# 10:35-12:10
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='17 Злотник'), subject=Subject(name='17 Інтелектуальні системи'), group=[Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=1)
#
#
# Classroom(room=43, is_big=True)
# Classroom(room=42, is_big=True)
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
#
# 12:20-13:55
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='2 Бобиль'), subject=Subject(name='2 Нейронні мережі'), group=[Group(name='МІ-42')], is_lecture=False, per_week=2)
#
#
# Classroom(room=43, is_big=True)
# Classroom(room=42, is_big=True)
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
# ----------------------------------------------------------------------------------------------------
# П'ЯТНИЦЯ
#
#
# 8:40-10:15
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='15 Крак'), subject=Subject(name='13 Розробка ПЗ під мобільні платформи'), group=[Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=False, per_week=1)
#
#
# Classroom(room=43, is_big=True)
# Classroom(room=42, is_big=True)
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
#
# 10:35-12:10
#
# Classroom(room=409, is_big=True)
# Classroom(room=43, is_big=True)
# Classroom(room=42, is_big=True)
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
#
# 12:20-13:55
#
# Classroom(room=409, is_big=True)
# Classroom(room=43, is_big=True)
# Classroom(room=42, is_big=True)
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
# ****************************************************************************************************
# ****************************************************************************************************
#
# ----------------------------------------------------------------------------------------------------
# ПОНЕДІЛОК
#
#
# 8:40-10:15
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='3 Закала'), subject=Subject(name='12 Проблеми штучного інтелекту'), group=Group(name='ТТП-41'), is_lecture=True, per_week=1)
#
#
# Classroom(room=43, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='8 Мисечко'), subject=Subject(name='3 Теорія прийняття рішень'), group=[Group(name='ТТП-42'), Group(name='ТК-41')], is_lecture=True, per_week=1)
#
#
# Classroom(room=42, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='1 Вергунова'), subject=Subject(name='1 Складність алгоритмів'), group=[Group(name='МІ-42')], is_lecture=True, per_week=1)
#
#
# Classroom(room=305, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='5 Мащенко'), subject=Subject(name='16 Теорія прийняття рішень'), group=Group(name='МІ-41'), is_lecture=False, per_week=1)
#
#
# Classroom(room=307, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='12 Красовська'), subject=Subject(name='7 Іноземна мова'), group=Group(name='ТК-41'), is_lecture=False, per_week=1)
#
#
# Classroom(room=203, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='21 Криволап'), subject=Subject(name='4 Інтелектуальні системи'), group=Group(name='ТТП-42'), is_lecture=False, per_week=1)
#
#
#
# 10:35-12:10
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='13 Шишацька'), subject=Subject(name='16 Теорія прийняття рішень'), group=Group(name='ТТП-41'), is_lecture=True, per_week=2)
#
#
# Classroom(room=43, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='11 Свистунов'), subject=Subject(name='8 Розробка ПЗ під мобільні платформи'), group=[Group(name='ТТП-42'), Group(name='ТК-41')], is_lecture=True, per_week=2)
#
#
# Classroom(room=42, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='14 Дорошенко'), subject=Subject(name='12 Проблеми штучного інтелекту'), group=[Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=2)
#
#
# Classroom(room=305, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='5 Мащенко'), subject=Subject(name='16 Теорія прийняття рішень'), group=Group(name='МІ-42'), is_lecture=False, per_week=1)
#
#
# Classroom(room=307, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='6 Тарануха'), subject=Subject(name='4 Інтелектуальні системи'), group=Group(name='МІ-41'), is_lecture=False, per_week=1)
#
#
# Classroom(room=203, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='7 Федорус'), subject=Subject(name='4 Інтелектуальні системи'), group=Group(name='ТТП-42'), is_lecture=False, per_week=1)
#
#
#
# 12:20-13:55
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='13 Шишацька'), subject=Subject(name='16 Теорія прийняття рішень'), group=Group(name='ТТП-41'), is_lecture=True, per_week=2)
#
#
# Classroom(room=43, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='11 Свистунов'), subject=Subject(name='8 Розробка ПЗ під мобільні платформи'), group=[Group(name='ТТП-42'), Group(name='ТК-41')], is_lecture=True, per_week=2)
#
#
# Classroom(room=42, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='14 Дорошенко'), subject=Subject(name='12 Проблеми штучного інтелекту'), group=[Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=2)
#
#
# Classroom(room=305, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='6 Тарануха'), subject=Subject(name='4 Інтелектуальні системи'), group=Group(name='МІ-42'), is_lecture=False, per_week=1)
#
#
# Classroom(room=307, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='10 Терещенко'), subject=Subject(name='15 Інформаційні системи'), group=Group(name='ТК-41'), is_lecture=False, per_week=2)
#
#
# Classroom(room=203, is_big=False)
# ----------------------------------------------------------------------------------------------------
# ВІВТОРОК
#
#
# 8:40-10:15
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='18 Башняков'), subject=Subject(name='10 Методи паралельних обчислень'), group=[Group(name='ТТП-42'), Group(name='ТК-41')], is_lecture=True, per_week=1)
#
#
# Classroom(room=43, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='16 Чернега'), subject=Subject(name='11 Розробка ПЗ'), group=[Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=2)
#
#
# Classroom(room=42, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='2 Бобиль'), subject=Subject(name='2 Нейронні мережі'), group=Group(name='ТТП-41'), is_lecture=True, per_week=2)
#
#
# Classroom(room=305, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='6 Тарануха'), subject=Subject(name='4 Інтелектуальні системи'), group=Group(name='ТК-41'), is_lecture=False, per_week=1)
#
#
# Classroom(room=307, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='10 Терещенко'), subject=Subject(name='15 Інформаційні системи'), group=Group(name='ТТП-42'), is_lecture=False, per_week=2)
#
#
# Classroom(room=203, is_big=False)
#
# 10:35-12:10
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='12 Красовська'), subject=Subject(name='9 Основи управління ІТ-проєктами'), group=[Group(name='ТТП-42'), Group(name='ТК-41')], is_lecture=True, per_week=2)
#
#
# Classroom(room=43, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='16 Чернега'), subject=Subject(name='11 Розробка ПЗ'), group=[Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=2)
#
#
# Classroom(room=42, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='4 Зінько'), subject=Subject(name='16 Теорія прийняття рішень'), group=Group(name='ТТП-41'), is_lecture=False, per_week=1)
#
#
# Classroom(room=305, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='10 Терещенко'), subject=Subject(name='13 Розробка ПЗ під мобільні платформи'), group=Group(name='ТТП-42'), is_lecture=False, per_week=2)
#
#
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
#
# 12:20-13:55
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='12 Красовська'), subject=Subject(name='9 Основи управління ІТ-проєктами'), group=[Group(name='ТТП-42'), Group(name='ТК-41')], is_lecture=True, per_week=2)
#
#
# Classroom(room=43, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='17 Злотник'), subject=Subject(name='14 Алгоритміка'), group=[Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=1)
#
#
# Classroom(room=42, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='13 Шишацька'), subject=Subject(name='4 Інтелектуальні системи'), group=Group(name='ТТП-41'), is_lecture=False, per_week=1)
#
#
# Classroom(room=305, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='10 Терещенко'), subject=Subject(name='15 Інформаційні системи'), group=Group(name='ТК-41'), is_lecture=False, per_week=2)
#
#
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
# ----------------------------------------------------------------------------------------------------
# СЕРЕДА
#
#
# 8:40-10:15
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='0 Пашко'), subject=Subject(name='0 Статистичне моделювання в задачах штучного інтелекту'), group=[Group(name='ТТП-41'), Group(name='ТТП-42'), Group(name='ТК-41'), Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=1)
#
#
# Classroom(room=43, is_big=True)
# Classroom(room=42, is_big=True)
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
#
# 10:35-12:10
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='9 Ткаченко'), subject=Subject(name="6 Основи комп'ютерної лінгвістики"), group=[Group(name='ТТП-41'), Group(name='ТТП-42'), Group(name='ТК-41'), Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=1)
#
#
# Classroom(room=43, is_big=True)
# Classroom(room=42, is_big=True)
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
#
# 12:20-13:55
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='17 Злотник'), subject=Subject(name='17 Інтелектуальні системи'), group=[Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=1)
#
#
# Classroom(room=43, is_big=True)
# Classroom(room=42, is_big=True)
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
# ----------------------------------------------------------------------------------------------------
# ЧЕТВЕР
#
#
# 8:40-10:15
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='4 Зінько'), subject=Subject(name='4 Інтелектуальні системи'), group=[Group(name='ТТП-41'), Group(name='ТТП-42'), Group(name='ТК-41'), Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=1)
#
#
# Classroom(room=43, is_big=True)
# Classroom(room=42, is_big=True)
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
#
# 10:35-12:10
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='5 Мащенко'), subject=Subject(name='16 Теорія прийняття рішень'), group=[Group(name='ТТП-41'), Group(name='ТТП-42'), Group(name='ТК-41'), Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=1)
#
#
# Classroom(room=43, is_big=True)
# Classroom(room=42, is_big=True)
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
#
# 12:20-13:55
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='2 Бобиль'), subject=Subject(name='2 Нейронні мережі'), group=[Group(name='МІ-42')], is_lecture=False, per_week=2)
#
#
# Classroom(room=43, is_big=True)
# Classroom(room=42, is_big=True)
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
# ----------------------------------------------------------------------------------------------------
# П'ЯТНИЦЯ
#
#
# 8:40-10:15
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='15 Крак'), subject=Subject(name='13 Розробка ПЗ під мобільні платформи'), group=[Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=False, per_week=1)
#
#
# Classroom(room=43, is_big=True)
# Classroom(room=42, is_big=True)
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
#
# 10:35-12:10
#
# Classroom(room=409, is_big=True)
# Classroom(room=43, is_big=True)
# Classroom(room=42, is_big=True)
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
#
# 12:20-13:55
#
# Classroom(room=409, is_big=True)
# Classroom(room=43, is_big=True)
# Classroom(room=42, is_big=True)
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
# ****************************************************************************************************
# ****************************************************************************************************
#
# ----------------------------------------------------------------------------------------------------
# ПОНЕДІЛОК
#
#
# 8:40-10:15
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='5 Мащенко'), subject=Subject(name='16 Теорія прийняття рішень'), group=[Group(name='ТТП-41'), Group(name='ТТП-42'), Group(name='ТК-41'), Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=1)
#
#
# Classroom(room=43, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='13 Шишацька'), subject=Subject(name='4 Інтелектуальні системи'), group=Group(name='ТТП-41'), is_lecture=False, per_week=1)
#
#
# Classroom(room=42, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='10 Терещенко'), subject=Subject(name='15 Інформаційні системи'), group=Group(name='ТТП-42'), is_lecture=False, per_week=2)
#
#
# Classroom(room=305, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='6 Тарануха'), subject=Subject(name='4 Інтелектуальні системи'), group=Group(name='ТК-41'), is_lecture=False, per_week=1)
#
#
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
#
# 10:35-12:10
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='4 Зінько'), subject=Subject(name='4 Інтелектуальні системи'), group=[Group(name='ТТП-41'), Group(name='ТТП-42'), Group(name='ТК-41'), Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=1)
#
#
# Classroom(room=43, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='10 Терещенко'), subject=Subject(name='13 Розробка ПЗ під мобільні платформи'), group=Group(name='ТТП-42'), is_lecture=False, per_week=2)
#
#
# Classroom(room=42, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='13 Шишацька'), subject=Subject(name='16 Теорія прийняття рішень'), group=Group(name='ТТП-41'), is_lecture=True, per_week=2)
#
#
# Classroom(room=305, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='5 Мащенко'), subject=Subject(name='16 Теорія прийняття рішень'), group=Group(name='МІ-41'), is_lecture=False, per_week=1)
#
#
# Classroom(room=307, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='6 Тарануха'), subject=Subject(name='4 Інтелектуальні системи'), group=Group(name='МІ-42'), is_lecture=False, per_week=1)
#
#
# Classroom(room=203, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='12 Красовська'), subject=Subject(name='7 Іноземна мова'), group=Group(name='ТК-41'), is_lecture=False, per_week=1)
#
#
#
# 12:20-13:55
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='0 Пашко'), subject=Subject(name='0 Статистичне моделювання в задачах штучного інтелекту'), group=[Group(name='ТТП-41'), Group(name='ТТП-42'), Group(name='ТК-41'), Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=1)
#
#
# Classroom(room=43, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='4 Зінько'), subject=Subject(name='16 Теорія прийняття рішень'), group=Group(name='ТТП-41'), is_lecture=False, per_week=1)
#
#
# Classroom(room=42, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='10 Терещенко'), subject=Subject(name='15 Інформаційні системи'), group=Group(name='ТК-41'), is_lecture=False, per_week=2)
#
#
# Classroom(room=305, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='21 Криволап'), subject=Subject(name='4 Інтелектуальні системи'), group=Group(name='ТТП-42'), is_lecture=False, per_week=1)
#
#
# Classroom(room=307, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='5 Мащенко'), subject=Subject(name='16 Теорія прийняття рішень'), group=Group(name='МІ-42'), is_lecture=False, per_week=1)
#
#
# Classroom(room=203, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='6 Тарануха'), subject=Subject(name='4 Інтелектуальні системи'), group=Group(name='МІ-41'), is_lecture=False, per_week=1)
#
#
# ----------------------------------------------------------------------------------------------------
# ВІВТОРОК
#
#
# 8:40-10:15
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='9 Ткаченко'), subject=Subject(name="6 Основи комп'ютерної лінгвістики"), group=[Group(name='ТТП-41'), Group(name='ТТП-42'), Group(name='ТК-41'), Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=1)
#
#
# Classroom(room=43, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='2 Бобиль'), subject=Subject(name='2 Нейронні мережі'), group=Group(name='ТТП-41'), is_lecture=True, per_week=2)
#
#
# Classroom(room=42, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='7 Федорус'), subject=Subject(name='4 Інтелектуальні системи'), group=Group(name='ТТП-42'), is_lecture=False, per_week=1)
#
#
# Classroom(room=305, is_big=False)		....................................................................................................
# Lesson(teacher=Teacher(name='10 Терещенко'), subject=Subject(name='15 Інформаційні системи'), group=Group(name='ТК-41'), is_lecture=False, per_week=2)
#
#
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
#
# 10:35-12:10
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='14 Дорошенко'), subject=Subject(name='12 Проблеми штучного інтелекту'), group=[Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=2)
#
#
# Classroom(room=43, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='12 Красовська'), subject=Subject(name='9 Основи управління ІТ-проєктами'), group=[Group(name='ТТП-42'), Group(name='ТК-41')], is_lecture=True, per_week=2)
#
#
# Classroom(room=42, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='3 Закала'), subject=Subject(name='12 Проблеми штучного інтелекту'), group=Group(name='ТТП-41'), is_lecture=True, per_week=1)
#
#
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
#
# 12:20-13:55
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='15 Крак'), subject=Subject(name='13 Розробка ПЗ під мобільні платформи'), group=[Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=False, per_week=1)
#
#
# Classroom(room=43, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='11 Свистунов'), subject=Subject(name='8 Розробка ПЗ під мобільні платформи'), group=[Group(name='ТТП-42'), Group(name='ТК-41')], is_lecture=True, per_week=2)
#
#
# Classroom(room=42, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='13 Шишацька'), subject=Subject(name='16 Теорія прийняття рішень'), group=Group(name='ТТП-41'), is_lecture=True, per_week=2)
#
#
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
# ----------------------------------------------------------------------------------------------------
# СЕРЕДА
#
#
# 8:40-10:15
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='16 Чернега'), subject=Subject(name='11 Розробка ПЗ'), group=[Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=2)
#
#
# Classroom(room=43, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='12 Красовська'), subject=Subject(name='9 Основи управління ІТ-проєктами'), group=[Group(name='ТТП-42'), Group(name='ТК-41')], is_lecture=True, per_week=2)
#
#
# Classroom(room=42, is_big=True)
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
#
# 10:35-12:10
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='17 Злотник'), subject=Subject(name='14 Алгоритміка'), group=[Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=1)
#
#
# Classroom(room=43, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='8 Мисечко'), subject=Subject(name='3 Теорія прийняття рішень'), group=[Group(name='ТТП-42'), Group(name='ТК-41')], is_lecture=True, per_week=1)
#
#
# Classroom(room=42, is_big=True)
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
#
# 12:20-13:55
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='2 Бобиль'), subject=Subject(name='2 Нейронні мережі'), group=[Group(name='МІ-42')], is_lecture=False, per_week=2)
#
#
# Classroom(room=43, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='11 Свистунов'), subject=Subject(name='8 Розробка ПЗ під мобільні платформи'), group=[Group(name='ТТП-42'), Group(name='ТК-41')], is_lecture=True, per_week=2)
#
#
# Classroom(room=42, is_big=True)
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
# ----------------------------------------------------------------------------------------------------
# ЧЕТВЕР
#
#
# 8:40-10:15
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='14 Дорошенко'), subject=Subject(name='12 Проблеми штучного інтелекту'), group=[Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=2)
#
#
# Classroom(room=43, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='18 Башняков'), subject=Subject(name='10 Методи паралельних обчислень'), group=[Group(name='ТТП-42'), Group(name='ТК-41')], is_lecture=True, per_week=1)
#
#
# Classroom(room=42, is_big=True)
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
#
# 10:35-12:10
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='16 Чернега'), subject=Subject(name='11 Розробка ПЗ'), group=[Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=2)
#
#
# Classroom(room=43, is_big=True)
# Classroom(room=42, is_big=True)
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
#
# 12:20-13:55
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='1 Вергунова'), subject=Subject(name='1 Складність алгоритмів'), group=[Group(name='МІ-42')], is_lecture=True, per_week=1)
#
#
# Classroom(room=43, is_big=True)
# Classroom(room=42, is_big=True)
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
# ----------------------------------------------------------------------------------------------------
# П'ЯТНИЦЯ
#
#
# 8:40-10:15
#
# Classroom(room=409, is_big=True)		....................................................................................................
# Lesson(teacher=Teacher(name='17 Злотник'), subject=Subject(name='17 Інтелектуальні системи'), group=[Group(name='МІ-41'), Group(name='МІ-42')], is_lecture=True, per_week=1)
#
#
# Classroom(room=43, is_big=True)
# Classroom(room=42, is_big=True)
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
#
# 10:35-12:10
#
# Classroom(room=409, is_big=True)
# Classroom(room=43, is_big=True)
# Classroom(room=42, is_big=True)
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
#
# 12:20-13:55
#
# Classroom(room=409, is_big=True)
# Classroom(room=43, is_big=True)
# Classroom(room=42, is_big=True)
# Classroom(room=305, is_big=False)
# Classroom(room=307, is_big=False)
# Classroom(room=203, is_big=False)
# MRV: 0.006994009017944336
# LCV: 0.24977517127990723
# Degree: 0.024701833724975586
